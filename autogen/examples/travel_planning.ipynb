# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_core.models import ModelFamily

# %%
model_client = OpenAIChatCompletionClient(
        # model="qwen2.5:14b",
        model="qwen2.5:7b",
        # model="llama3.2:3b",
        base_url="http://localhost:11434/v1",
        api_key="placeholder",
        model_info={
            "vision": False,
            "function_calling": True,
            "json_output": False,
            "family": ModelFamily.ANY,
        },
    )

planner_agent = AssistantAgent(
    "planner_agent",
    # model_client=OpenAIChatCompletionClient(model="gpt-4o"),
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    # model_client=OpenAIChatCompletionClient(model="gpt-4o"),
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    # model_client=OpenAIChatCompletionClient(model="gpt-4o"),
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    # model_client=OpenAIChatCompletionClient(model="gpt-4o"),
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, please respond with TERMINATE to end the planning.",
)

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
# await Console(group_chat.run_stream(task="Plan a 3 day trip to Shanghai."), output_stats=True)
await Console(group_chat.run_stream(task="制定去上海的 3 天旅行计划"), output_stats=True)
# Out:
# ---------- user ----------
# 制定去上海的 3 天旅行计划
# ---------- planner_agent ----------
# 当然可以！根据您的需求与时间安排，我为您准备了一份详细的三天两晚上海旅游行程。在上海，您可以感受到中国现代都市的气息、领略到江南水乡的魅力以及体验到深厚的历史文化和丰富的人文景观。
#
# **1. 第一天：上海城市探索**
# - 早上：
#     - 参观外滩和东方明珠塔（建议乘坐观光电梯去顶部观景台欣赏全市风貌）。
# - 中午/下午：
#     - 前往南京路步行街尝尝当地的特色小吃(例如小杨生煎、南翔小笼包)。
#     - 您还可以逛逛老洋房，了解旧上海的建筑文化。
# - 晚上：
#     - 散步于城隍庙感受古色古香的小弄堂并品尝经典的小吃。
#
# **2. 第二天：浦东区游览与迪士尼公园之行**
# - 上午：
#    - 访问上海博物馆欣赏中国古代艺术品展览。
# - 中午/下午：
#    - 去陆家嘴金融中心观赏高楼大厦，并在周边享用一顿丰盛的午餐或晚餐。
# - 下午晚些时候：
#    - 前往上海迪士尼乐园，尝试各种游乐设施和观看表演。
#
# **3. 第三天：古镇与博物馆文化之旅**
# - 整个上午到下午：
#     - 可以安排半天去附近的周浦花海观赏大片五彩斑斓的鲜花；
#     - 然后在黄浦江边漫步走走，欣赏一下浦东新区风光。
# - 下午/晚上：
#    - 在豫园与南翔古猗园等地感受古典园林的典雅之美并品尝当地美食。最后回到酒店稍作休息，整理好行李即可返回家中。
#
# 以上就是您在上海三天两夜旅游行程表。希望这些建议能够帮助到你~
# [Prompt tokens: 42, Completion tokens: 383]
# ---------- local_agent ----------
# 这份三天两晚上海旅行计划相当周密且充满活力，涵盖了城市标志性景点、历史悠久的文化遗迹以及现代娱乐休闲的选择。不过，如果您想让这个行程更加个性化和丰富一些，可以考虑以下几个建议：
#
# ### 第一天：上海城市探索
#
# - 早餐时可以选择本地的小吃摊尝一尝新鲜出炉的鲜肉包。
# - 上午9:00至12:30：
#    - 访问外滩，沿着黄浦江边漫步并欣赏东方明珠塔等标志性建筑。
#    - 可以在10:30左右乘坐电梯登顶东方明珠塔顶层观景台（注意要避开高峰期）。
#
# - 下午13:00至16:00：
#    - 前往静安寺附近或南京路步行街享用当地美食，例如品尝外滩8号的特色午餐。
#    - 在华山路、南京路上闲逛，欣赏一些时尚精品店和古董店。
#
# ### 第二天：浦东区游览与迪士尼公园之行
#
# - 早餐时可在迪士尼乐园内的米奇小镇咖啡馆里享用美味的食物。
# - 上午10:30至12:30：
#    - 参观上海博物馆，欣赏中国古代雕塑、绘画和瓷器等收藏品。
#
# - 下午14:00至17:00：
#    - 从陆家嘴金融区乘坐地铁或打车前往迪士尼乐园。
#    - 在主题乐园中度过愉快的下午时光，尝试各种游乐项目及观看表演（晚上还可以参加烟花秀）。
#
# ### 第三天：古镇与博物馆文化之旅
#
# - 晨间散步游览田子坊，体验艺术和创意工作室的艺术氛围；享受这里的咖啡屋、街头小吃等。
#
# - 上午10:30至14:00：
#    - 参观南翔古镇及古猗园，感受传统园林的魅力。
#    - 在古猗园附近享用午餐(建议尝尝当地农家菜)。
#
# - 下午15:00至18:00：
#    - 前往豫园商城漫步参观古色古香的老建筑，并在附近的茶馆里休息一小会儿。随后可前往思南公馆区域闲逛，欣赏海派特色建筑。
#
# 希望这些建议能为您的上海之行锦上添花！当然，具体行程和计划可根据个人兴趣进行调整哦~
# [Prompt tokens: 434, Completion tokens: 506]
# ---------- language_agent ----------
# 这份三天两晚的上海旅游计划已经相当周密且富有内容，涵盖了城市标志性景点、历史悠久的文化遗迹以及现代娱乐休闲的选择。针对语言或沟通方面，您可以在计划中加入一些实用建议来帮助克服潜在的语言障碍：
#
# ### 语言与沟通提示
#
# 1. **推荐使用中文导游APP**：
#    - 可下载如“携程导览”、“美团旅行”等应用，这些应用程序能够提供景点讲解、交通导航以及周边餐饮推荐功能。它们通常支持多国语言切换，包括中文普通话和上海话。
#
# 2. **了解常用表达词句**：
#    - 常用于日常交流的短语如“谢谢”（非常感谢用的是“谢谢侬” / “xiè xie nóng”）、“对不起”（“duì bù qǐ”）等，可以让您在与当地人沟通时更加自然。
#
# 3. **注意餐饮消费时的文化特点**：
#    - 在上海就餐点餐时可以使用餐厅菜单上的图片或拼音指示菜品。建议提前熟悉一些基本的中式菜肴名称及其英文、中文拼音对应。
#
# 4. **了解交通信息和导航工具**：
#    - 上海地铁和公交线路众多，可以通过“Metro Shanghai”应用获取最新的地铁运营信息；另外，“高德地图”App也支持路线规划功能，并且提供了详细的地铁换乘指南。
#
# 5. **使用翻译应用程序进行即时交流**：
#    - 携程的翻译插件可用于即时对话时快速获得准确的中文和英文翻译。
#
# ### 具体行程融入语言策略
#
# - **第一天：外滩游览**
#   - 提前研究外滩周围景点名称，如东方明珠塔（Eastern Pearl TV Tower），方便向导或使用地图软件。
#
# - **第二天：陆家嘴金融区至迪士尼乐园**
#   - 使用“支付宝”的公共交通引导功能，它可以帮助您顺利找到路径并能使用中文与司机沟通。
#
# - **第三天：南京路步行街逛吃**
#   - 在进入餐厅之前尝试浏览食物菜单或用手机拍照，以便和店员进行简单的交流确认餐点。
#
# 总体来说，您的计划很全面且细致，并已考虑到了部分语言适应建议。继续保持下去吧！如果您有更多需要调整的地方或者想要更多细节，随时告诉我哦~
# [Prompt tokens: 963, Completion tokens: 482]
# ---------- travel_summary_agent ----------
# ### 终止
#
# 此为终稿：
#
# #### 三天两晚上海旅行行程表
# **第一天：上海城市探索**
# 1. **上午9:00-12:30：外滩&东方明珠塔**
#    - 参观外滩，欣赏黄浦江沿岸的地标建筑。
#    - 约11:00登顶东方明珠塔（乘坐观光电梯）。
#
# 2. **中午/下午13:00-16:00：南京路步行街**
#    - 品尝经典当地小吃如小杨生煎、南翔小笼包。
#    - 走访传统老洋房，了解旧上海历史。
#
# 3. **晚上18:00-20:00：城隍庙夜游**
#    - 散步于上海著名的古色古香街区体验传统文化。
#    - 品尝经典小吃如梨膏糖、特色汤团等。
#
# **第二天：浦东区游览与迪士尼公园之行**
# 1. **上午10:30-12:30：上海博物馆**
#    - 参观中国传统艺术品展览，欣赏珍贵文物。
#
# 2. **中午/下午13:30-16:00：陆家嘴金融中心**
#    - 观赏壮观的摩天大楼群。
#    - 在周边享用午餐或晚餐。
#
# 3. **下午晚些时候：上海迪士尼乐园**
#    - 体验各种游乐设施，观看精彩表演。
#    - 晚上观赏烟花秀（如果当天有安排的话）。
#
# **第三天：古镇与博物馆文化之旅**
# 1. **上午9:00-12:00：周浦花海观光**
#    - 赏玩大面积盛开的五彩鲜花。
#
# 2. **中午/下午13:00-16:00：田子坊步行街**
#    - 体验艺术和创意工作室氛围。
#    - 尝试当地小食，享受特色咖啡馆及街头小吃。
#
# 3. **下午15:00-18:00：豫园与南翔古猗园**
#    - 漫步古色古香的小巷，感受传统园林之美。
#    - 在附近的茶馆休息一会儿。
#    - 逛逛思南公馆区域，欣赏海派建筑风格。
#
# 4. **晚上20:00左右返回酒店或火车站**
#
# 请确保携带好手机、充电器和翻译应用，在需要时辅助沟通。愉快地在上海畅游吧！
#
# TERMINATE
# [Prompt tokens: 1461, Completion tokens: 541]
# ---------- Summary ----------
# Number of messages: 5
# Finish reason: Text 'TERMINATE' mentioned
# Total prompt tokens: 2900
# Total completion tokens: 1912
# Duration: 107.06 seconds
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='制定去上海的 3 天旅行计划', type='TextMessage'), TextMessage(source='planner_agent', models_usage=RequestUsage(prompt_tokens=42, completion_tokens=383), metadata={}, content='当然可以！根据您的需求与时间安排，我为您准备了一份详细的三天两晚上海旅游行程。在上海，您可以感受到中国现代都市的气息、领略到江南水乡的魅力以及体验到深厚的历史文化和丰富的人文景观。\n\n**1. 第一天：上海城市探索**\n- 早上：\n    - 参观外滩和东方明珠塔（建议乘坐观光电梯去顶部观景台欣赏全市风貌）。\n- 中午/下午：\n    - 前往南京路步行街尝尝当地的特色小吃(例如小杨生煎、南翔小笼包)。\n    - 您还可以逛逛老洋房，了解旧上海的建筑文化。\n- 晚上：\n    - 散步于城隍庙感受古色古香的小弄堂并品尝经典的小吃。\n\n**2. 第二天：浦东区游览与迪士尼公园之行**\n- 上午：\n   - 访问上海博物馆欣赏中国古代艺术品展览。\n- 中午/下午：\n   - 去陆家嘴金融中心观赏高楼大厦，并在周边享用一顿丰盛的午餐或晚餐。\n- 下午晚些时候：\n   - 前往上海迪士尼乐园，尝试各种游乐设施和观看表演。\n\n**3. 第三天：古镇与博物馆文化之旅**\n- 整个上午到下午：\n    - 可以安排半天去附近的周浦花海观赏大片五彩斑斓的鲜花；\n    - 然后在黄浦江边漫步走走，欣赏一下浦东新区风光。\n- 下午/晚上：\n   - 在豫园与南翔古猗园等地感受古典园林的典雅之美并品尝当地美食。最后回到酒店稍作休息，整理好行李即可返回家中。\n\n以上就是您在上海三天两夜旅游行程表。希望这些建议能够帮助到你~', type='TextMessage'), TextMessage(source='local_agent', models_usage=RequestUsage(prompt_tokens=434, completion_tokens=506), metadata={}, content='这份三天两晚上海旅行计划相当周密且充满活力，涵盖了城市标志性景点、历史悠久的文化遗迹以及现代娱乐休闲的选择。不过，如果您想让这个行程更加个性化和丰富一些，可以考虑以下几个建议：\n\n### 第一天：上海城市探索\n\n- 早餐时可以选择本地的小吃摊尝一尝新鲜出炉的鲜肉包。\n- 上午9:00至12:30：\n   - 访问外滩，沿着黄浦江边漫步并欣赏东方明珠塔等标志性建筑。\n   - 可以在10:30左右乘坐电梯登顶东方明珠塔顶层观景台（注意要避开高峰期）。\n\n- 下午13:00至16:00：\n   - 前往静安寺附近或南京路步行街享用当地美食，例如品尝外滩8号的特色午餐。\n   - 在华山路、南京路上闲逛，欣赏一些时尚精品店和古董店。\n\n### 第二天：浦东区游览与迪士尼公园之行\n\n- 早餐时可在迪士尼乐园内的米奇小镇咖啡馆里享用美味的食物。\n- 上午10:30至12:30：\n   - 参观上海博物馆，欣赏中国古代雕塑、绘画和瓷器等收藏品。\n\n- 下午14:00至17:00：\n   - 从陆家嘴金融区乘坐地铁或打车前往迪士尼乐园。\n   - 在主题乐园中度过愉快的下午时光，尝试各种游乐项目及观看表演（晚上还可以参加烟花秀）。\n\n### 第三天：古镇与博物馆文化之旅\n\n- 晨间散步游览田子坊，体验艺术和创意工作室的艺术氛围；享受这里的咖啡屋、街头小吃等。\n\n- 上午10:30至14:00：\n   - 参观南翔古镇及古猗园，感受传统园林的魅力。\n   - 在古猗园附近享用午餐(建议尝尝当地农家菜)。\n\n- 下午15:00至18:00：\n   - 前往豫园商城漫步参观古色古香的老建筑，并在附近的茶馆里休息一小会儿。随后可前往思南公馆区域闲逛，欣赏海派特色建筑。\n\n希望这些建议能为您的上海之行锦上添花！当然，具体行程和计划可根据个人兴趣进行调整哦~', type='TextMessage'), TextMessage(source='language_agent', models_usage=RequestUsage(prompt_tokens=963, completion_tokens=482), metadata={}, content='这份三天两晚的上海旅游计划已经相当周密且富有内容，涵盖了城市标志性景点、历史悠久的文化遗迹以及现代娱乐休闲的选择。针对语言或沟通方面，您可以在计划中加入一些实用建议来帮助克服潜在的语言障碍：\n\n### 语言与沟通提示\n\n1. **推荐使用中文导游APP**：\n   - 可下载如“携程导览”、“美团旅行”等应用，这些应用程序能够提供景点讲解、交通导航以及周边餐饮推荐功能。它们通常支持多国语言切换，包括中文普通话和上海话。\n   \n2. **了解常用表达词句**：\n   - 常用于日常交流的短语如“谢谢”（非常感谢用的是“谢谢侬” / “xiè xie nóng”）、“对不起”（“duì bù qǐ”）等，可以让您在与当地人沟通时更加自然。\n   \n3. **注意餐饮消费时的文化特点**：\n   - 在上海就餐点餐时可以使用餐厅菜单上的图片或拼音指示菜品。建议提前熟悉一些基本的中式菜肴名称及其英文、中文拼音对应。\n\n4. **了解交通信息和导航工具**：\n   - 上海地铁和公交线路众多，可以通过“Metro Shanghai”应用获取最新的地铁运营信息；另外，“高德地图”App也支持路线规划功能，并且提供了详细的地铁换乘指南。\n   \n5. **使用翻译应用程序进行即时交流**：\n   - 携程的翻译插件可用于即时对话时快速获得准确的中文和英文翻译。\n\n### 具体行程融入语言策略\n\n- **第一天：外滩游览**\n  - 提前研究外滩周围景点名称，如东方明珠塔（Eastern Pearl TV Tower），方便向导或使用地图软件。\n  \n- **第二天：陆家嘴金融区至迪士尼乐园**\n  - 使用“支付宝”的公共交通引导功能，它可以帮助您顺利找到路径并能使用中文与司机沟通。\n\n- **第三天：南京路步行街逛吃**\n  - 在进入餐厅之前尝试浏览食物菜单或用手机拍照，以便和店员进行简单的交流确认餐点。  \n\n总体来说，您的计划很全面且细致，并已考虑到了部分语言适应建议。继续保持下去吧！如果您有更多需要调整的地方或者想要更多细节，随时告诉我哦~', type='TextMessage'), TextMessage(source='travel_summary_agent', models_usage=RequestUsage(prompt_tokens=1461, completion_tokens=541), metadata={}, content='### 终止\n\n此为终稿：\n\n#### 三天两晚上海旅行行程表\n**第一天：上海城市探索**\n1. **上午9:00-12:30：外滩&东方明珠塔**\n   - 参观外滩，欣赏黄浦江沿岸的地标建筑。\n   - 约11:00登顶东方明珠塔（乘坐观光电梯）。\n\n2. **中午/下午13:00-16:00：南京路步行街**\n   - 品尝经典当地小吃如小杨生煎、南翔小笼包。\n   - 走访传统老洋房，了解旧上海历史。\n\n3. **晚上18:00-20:00：城隍庙夜游**\n   - 散步于上海著名的古色古香街区体验传统文化。\n   - 品尝经典小吃如梨膏糖、特色汤团等。\n\n**第二天：浦东区游览与迪士尼公园之行**\n1. **上午10:30-12:30：上海博物馆**\n   - 参观中国传统艺术品展览，欣赏珍贵文物。\n\n2. **中午/下午13:30-16:00：陆家嘴金融中心**\n   - 观赏壮观的摩天大楼群。\n   - 在周边享用午餐或晚餐。\n\n3. **下午晚些时候：上海迪士尼乐园**\n   - 体验各种游乐设施，观看精彩表演。\n   - 晚上观赏烟花秀（如果当天有安排的话）。\n\n**第三天：古镇与博物馆文化之旅**\n1. **上午9:00-12:00：周浦花海观光**\n   - 赏玩大面积盛开的五彩鲜花。\n\n2. **中午/下午13:00-16:00：田子坊步行街**\n   - 体验艺术和创意工作室氛围。\n   - 尝试当地小食，享受特色咖啡馆及街头小吃。\n\n3. **下午15:00-18:00：豫园与南翔古猗园**\n   - 漫步古色古香的小巷，感受传统园林之美。\n   - 在附近的茶馆休息一会儿。\n   - 逛逛思南公馆区域，欣赏海派建筑风格。\n\n4. **晚上20:00左右返回酒店或火车站**\n\n请确保携带好手机、充电器和翻译应用，在需要时辅助沟通。愉快地在上海畅游吧！\n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mention ...
