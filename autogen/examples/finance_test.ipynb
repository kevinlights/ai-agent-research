# %%
import yfinance as yf
from datetime import datetime, timedelta
from pytz import timezone  # type: ignore

ticker = "AAPL"
stock = yf.Ticker(ticker)

# %%
end_date = datetime.now(timezone("UTC"))
start_date = end_date - timedelta(days=3)
hist = stock.history(start=start_date, end=end_date)

# %%
# IMPORT THE LIBRARY
import yfinance as yf
from datetime import datetime

# CREATE TICKER INSTANCE FOR AMAZON
tsla = yf.Ticker("TSLA")

# GET TODAYS DATE AND CONVERT IT TO A STRING WITH YYYY-MM-DD FORMAT (YFINANCE EXPECTS THAT FORMAT)
end_date = datetime.now().strftime('%Y-%m-%d')
tsla_hist = tsla.history(start='2023-01-01',end=end_date)
print(tsla_hist)

# %%
import akshare as ak

# 获取上证指数的历史数据
stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="sh000001", period="daily", start_date="20220101", end_date="20221231", adjust="qfq")

# 查看数据
print(stock_zh_a_hist_df.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import akshare as ak

stock_zh_a_hist_df = ak.stock_zh_a_hist(
    symbol="600734", 
    period="daily", 
    start_date="20050501", 
    end_date="20050520", 
    adjust="hfq"
)
print(stock_zh_a_hist_df)
# Out:
#            日期    股票代码    开盘    收盘    最高    最低    成交量        成交额       振幅  \
# 0  2005-05-09  600734 -0.13 -0.53  0.00 -0.53   7912  1571616.0   407.69
# 1  2005-05-10  600734 -0.53 -0.50 -0.36 -0.79   5978  1150869.0   -81.13
# 2  2005-05-11  600734 -0.50 -0.30 -0.20 -0.69   8415  1651719.0   -98.00
# 3  2005-05-12  600734 -0.33 -0.20  0.00 -0.43  10721  2175707.0  -143.33
# 4  2005-05-13  600734 -0.33 -0.13  0.07 -0.40   7661  1569427.0  -235.00
# 5  2005-05-16  600734 -0.30 -0.10  0.10 -0.40  11218  2324469.0  -384.62
# 6  2005-05-17  600734 -0.10  0.04  0.13 -0.23  12758  2682900.0  -360.00
# 7  2005-05-18  600734  0.00  0.20  0.27 -0.13  10709  2261494.0  1000.00
# 8  2005-05-19  600734  0.10  0.07  0.17 -0.06   7503  1589463.0   115.00
# 9  2005-05-20  600734  0.07  0.00  0.13 -0.03   6404  1355000.0   228.57
#
#       涨跌幅   涨跌额   换手率
# 0 -507.69 -0.66  0.60
# 1    5.66  0.03  0.45
# 2   40.00  0.20  0.63
# 3   33.33  0.10  0.81
# 4   35.00  0.07  0.58
# 5   23.08  0.03  0.85
# 6  140.00  0.14  0.96
# 7  400.00  0.16  0.81
# 8  -65.00 -0.13  0.57
# 9 -100.00 -0.07  0.48

# %%
# https://akshare.akfamily.xyz/data/stock/stock.html#id58

import akshare as ak

stock_us_hist_df = ak.stock_us_hist(
    symbol="106.TTE",
    period="daily",
    start_date="20200101",
    end_date="20240214",
    adjust="qfq",
)
print(stock_us_hist_df)
# Out:
#               日期     开盘     收盘      最高     最低      成交量          成交额    振幅  \
# 0     2020-01-02  55.14  55.27  55.280  54.83  1166549   64267605.0  0.81
# 1     2020-01-03  55.27  55.47  55.720  55.22  1518977   84342940.0  0.90
# 2     2020-01-06  56.73  56.51  56.910  56.17  3516935  198886813.0  1.33
# 3     2020-01-07  56.31  56.19  56.330  55.70  2464108  138120786.0  1.11
# 4     2020-01-08  55.94  55.85  56.100  55.61  2831404  158168344.0  0.87
# ...          ...    ...    ...     ...    ...      ...          ...   ...
# 1032  2024-02-08  63.39  64.19  64.330  63.28  3348869  214143178.0  1.67
# 1033  2024-02-09  64.41  64.31  64.530  64.09  3474556  223631050.0  0.69
# 1034  2024-02-12  64.40  64.63  64.820  64.19  3213256  207519393.0  0.98
# 1035  2024-02-13  65.21  64.43  65.280  64.11  3306680  212993175.0  1.81
# 1036  2024-02-14  64.73  64.63  65.035  64.38  4014478  259516349.0  1.02
#
#        涨跌幅   涨跌额   换手率
# 0    -0.05 -0.03  0.04
# 1     0.36  0.20  0.06
# 2     1.87  1.04  0.14
# 3    -0.57 -0.32  0.09
# 4    -0.61 -0.34  0.11
# ...    ...   ...   ...
# 1032  1.81  1.14  0.14
# 1033  0.19  0.12  0.15
# 1034  0.50  0.32  0.14
# 1035 -0.31 -0.20  0.14
# 1036  0.31  0.20  0.17
#
# [1037 rows x 11 columns]

# %%
# https://akshare.akfamily.xyz/data/stock/stock.html#id61
import akshare as ak

stock_us_daily_df = ak.stock_us_daily(symbol="AAPL", adjust="")
print(stock_us_daily_df)
# Out:
#            date     open      high     low   close      volume
# 0    1984-09-07   26.500   26.8700   26.25   26.50   2981600.0
# 1    1984-09-10   26.500   26.6200   25.87   26.37   2346400.0
# 2    1984-09-11   26.620   27.3700   26.62   26.87   5444000.0
# 3    1984-09-12   26.870   27.0000   26.12   26.12   4773600.0
# 4    1984-09-13   27.500   27.6200   27.50   27.50   7429600.0
# ...         ...      ...       ...     ...     ...         ...
# 9650 2025-03-10  235.540  236.1600  224.22  227.48  72070924.0
# 9651 2025-03-11  223.805  225.8399  217.45  220.84  76137395.0
# 9652 2025-03-12  220.140  221.7500  214.91  216.98  62546947.0
# 9653 2025-03-13  215.950  216.8394  208.42  209.68  61368329.0
# 9654 2025-03-14  211.250  213.9500  209.58  213.49  60107524.0
#
# [9655 rows x 6 columns]

# %%
stock_us_daily_df[stock_us_daily_df['date'] > '2025-03-01']
# Out:
#            date     open      high       low   close      volume
# 9645 2025-03-03  241.790  244.0272  236.1120  238.03  47183985.0
# 9646 2025-03-04  237.705  240.0700  234.6800  235.93  53797735.0
# 9647 2025-03-05  235.420  236.5500  229.2300  235.74  47227643.0
# 9648 2025-03-06  234.435  237.8600  233.1581  235.33  45170419.0
# 9649 2025-03-07  235.105  241.3700  234.7600  239.07  46273564.0
# 9650 2025-03-10  235.540  236.1600  224.2200  227.48  72070924.0
# 9651 2025-03-11  223.805  225.8399  217.4500  220.84  76137395.0
# 9652 2025-03-12  220.140  221.7500  214.9100  216.98  62546947.0
# 9653 2025-03-13  215.950  216.8394  208.4200  209.68  61368329.0
# 9654 2025-03-14  211.250  213.9500  209.5800  213.49  60107524.0

# %%
import os
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import akshare as ak

from pytz import timezone  # type: ignore

DATE_FMT = "%Y-%m-%d"

# Get historical data (1 year of data to ensure we have enough for 200-day MA)
end_date = datetime.now(timezone("UTC"))
start_date = end_date - timedelta(days=365)
# hist = stock.history(start=start_date, end=end_date)
stock_us_daily_df[
    (stock_us_daily_df["date"] >= start_date.strftime(DATE_FMT))
    & (stock_us_daily_df["date"] <= end_date.strftime(DATE_FMT))
]
# Out:
#            date     open      high     low   close       volume
# 9406 2024-03-18  175.570  177.7100  173.52  173.72   75604154.0
# 9407 2024-03-19  174.340  176.6050  173.03  176.08   55215164.0
# 9408 2024-03-20  175.720  178.6700  175.09  178.67   53423022.0
# 9409 2024-03-21  177.050  177.4900  170.84  171.37  106181174.0
# 9410 2024-03-22  171.760  173.0500  170.06  172.28   71159977.0
# ...         ...      ...       ...     ...     ...          ...
# 9650 2025-03-10  235.540  236.1600  224.22  227.48   72070924.0
# 9651 2025-03-11  223.805  225.8399  217.45  220.84   76137395.0
# 9652 2025-03-12  220.140  221.7500  214.91  216.98   62546947.0
# 9653 2025-03-13  215.950  216.8394  208.42  209.68   61368329.0
# 9654 2025-03-14  211.250  213.9500  209.58  213.49   60107524.0
#
# [249 rows x 6 columns]

# %%
import akshare as ak

stock_us_hist_df = ak.stock_us_hist(symbol='106.TTE', period="daily", start_date="20200101", end_date="20240214", adjust="qfq")
print(stock_us_hist_df)
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x12cba3e20>
# Traceback (most recent call last):
#   File "/Users/kevinlights/app/miniforge3/envs/open_manus/lib/python3.12/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/kevinlights/app/miniforge3/envs/open_manus/lib/python3.12/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
#     ^^^^^^^^^
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
#               日期      开盘      收盘      最高      最低      成交量          成交额    振幅  \
# 0     2020-01-02  39.230  39.360  39.370  38.920  1166549   64267605.0  1.15
# 1     2020-01-03  39.360  39.560  39.810  39.310  1518977   84342940.0  1.27
# 2     2020-01-06  40.820  40.600  41.000  40.260  3516935  198886813.0  1.87
# 3     2020-01-07  40.400  40.280  40.420  39.790  2464108  138120786.0  1.55
# 4     2020-01-08  40.030  39.940  40.190  39.700  2831404  158168344.0  1.22
# ...          ...     ...     ...     ...     ...      ...          ...   ...
# 1032  2024-02-08  60.036  60.836  60.976  59.926  3348869  214143178.0  1.76
# 1033  2024-02-09  61.056  60.956  61.176  60.736  3474556  223631050.0  0.72
# 1034  2024-02-12  61.046  61.276  61.466  60.836  3213256  207519393.0  1.03
# 1035  2024-02-13  61.856  61.076  61.926  60.756  3306680  212993175.0  1.91
# 1036  2024-02-14  61.376  61.276  61.681  61.026  4014478  259516349.0  1.07
#
#        涨跌幅    涨跌额   换手率
# 0     0.20  0.079  0.04
# 1     0.51  0.200  0.06
# 2     2.63  1.040  0.14
# 3    -0.79 -0.320  0.09
# 4    -0.84 -0.340  0.11
# ...    ...    ...   ...
# 1032  1.91  1.140  0.14
# 1033  0.20  0.120  0.15
# 1034  0.52  0.320  0.14
# 1035 -0.33 -0.200  0.14
# 1036  0.33  0.200  0.17
#
# [1037 rows x 11 columns]

# %%
# ak.get_us_stock_name()

# %%
import os
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import akshare as ak

from pytz import timezone  # type: ignore

DATE_FMT = "%Y-%m-%d"

# Get historical data (1 year of data to ensure we have enough for 200-day MA)
end_date = datetime.now(timezone("UTC"))
start_date = end_date - timedelta(days=365)
# hist = stock.history(start=start_date, end=end_date)
hist = stock_us_daily_df[
    (stock_us_daily_df["date"] >= start_date.strftime(DATE_FMT))
    & (stock_us_daily_df["date"] <= end_date.strftime(DATE_FMT))
]
print(len(hist))
ytd_start = datetime(end_date.year, 1, 1, tzinfo=timezone("UTC")).strftime(DATE_FMT)
print(ytd_start)
ytd_data = hist.loc[ytd_start:]  # type: ignore[misc]
# Out:
# 249
# 2025-01-01

# %%
def analyze_stock(ticker: str) -> dict:  # type: ignore[type-arg]
    import os
    from datetime import datetime, timedelta
    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    import akshare as ak
    import yfinance as yf
    from pytz import timezone  # type: ignore

    # https://akshare.akfamily.xyz/data/stock/stock.html#id61
    import akshare as ak

    # stock = yf.Ticker(ticker)

    stock_us_daily_df = ak.stock_us_daily(symbol=ticker, adjust="")
    # print(stock_us_daily_df)
    DATE_FMT = "%Y-%m-%d"
    print(len(stock_us_daily_df))
    stock_us_daily_df.to_csv(f"stock_us_daily_df_{ticker}.csv", index=False)

    # Get historical data (1 year of data to ensure we have enough for 200-day MA)
    end_date = datetime.now(timezone("UTC"))
    start_date = end_date - timedelta(days=365)
    # hist = stock.history(start=start_date, end=end_date)

    hist = stock_us_daily_df[
        (stock_us_daily_df["date"] >= start_date.strftime(DATE_FMT))
        & (stock_us_daily_df["date"] <= end_date.strftime(DATE_FMT))
    ]
    print(len(hist))

    # Ensure we have data
    if hist.empty:
        return {"error": "No historical data available for the specified ticker."}

    # Compute basic statistics and additional metrics
    # current_price = stock.info.get("currentPrice", hist["close"].iloc[-1])
    # year_high = stock.info.get("fiftyTwoWeekHigh", hist["high"].max())
    # year_low = stock.info.get("fiftyTwoWeekLow", hist["low"].min())

    current_price = hist["close"].iloc[-1]
    year_high = hist["high"].max()
    year_low = hist["low"].min()

    # Calculate 50-day and 200-day moving averages
    ma_50 = hist["close"].rolling(window=50).mean().iloc[-1]
    ma_200 = hist["close"].rolling(window=200).mean().iloc[-1]

    # Calculate YTD price change and percent change
    ytd_start = datetime(end_date.year, 1, 1, tzinfo=timezone("UTC")).strftime(DATE_FMT)
    ytd_data = hist.loc[ytd_start:]  # type: ignore[misc]
    if not ytd_data.empty:
        price_change = ytd_data["close"].iloc[-1] - ytd_data["close"].iloc[0]
        percent_change = (price_change / ytd_data["close"].iloc[0]) * 100
    else:
        price_change = percent_change = np.nan

    # Determine trend
    if pd.notna(ma_50) and pd.notna(ma_200):
        if ma_50 > ma_200:
            trend = "Upward"
        elif ma_50 < ma_200:
            trend = "Downward"
        else:
            trend = "Neutral"
    else:
        trend = "Insufficient data for trend analysis"

    # Calculate volatility (standard deviation of daily returns)
    daily_returns = hist["close"].pct_change().dropna()
    volatility = daily_returns.std() * np.sqrt(252)  # Annualized volatility

    # Create result dictionary
    result = {
        "ticker": ticker,
        "current_price": current_price,
        "52_week_high": year_high,
        "52_week_low": year_low,
        "50_day_ma": ma_50,
        "200_day_ma": ma_200,
        "ytd_price_change": price_change,
        "ytd_percent_change": percent_change,
        "trend": trend,
        "volatility": volatility,
    }

    # Convert numpy types to Python native types for better JSON serialization
    for key, value in result.items():
        if isinstance(value, np.generic):
            result[key] = value.item()

    # Generate plot
    plt.figure(figsize=(12, 6))
    plt.plot(hist.index, hist["close"], label="Close Price")
    plt.plot(hist.index, hist["close"].rolling(window=50).mean(), label="50-day MA")
    plt.plot(hist.index, hist["close"].rolling(window=200).mean(), label="200-day MA")
    plt.title(f"{ticker} Stock Price (Past Year)")
    plt.xlabel("Date")
    plt.ylabel("Price ($)")
    plt.legend()
    plt.grid(True)

    # Save plot to file
    os.makedirs("coding", exist_ok=True)
    plot_file_path = f"coding/{ticker}_stockprice.png"
    plt.savefig(plot_file_path)
    print(f"Plot saved as {plot_file_path}")
    result["plot_file_path"] = plot_file_path

    return result


analyze_stock("AAPL")
# Out:
# 9655
# 249
# Plot saved as coding/AAPL_stockprice.png
# {'ticker': 'AAPL',
#  'current_price': 213.49,
#  '52_week_high': 260.1,
#  '52_week_low': 164.08,
#  '50_day_ma': 234.9298,
#  '200_day_ma': 227.77270000000001,
#  'ytd_price_change': 39.77000000000001,
#  'ytd_percent_change': 22.89316140916418,
#  'trend': 'Upward',
#  'volatility': 0.24949738014679793,
#  'plot_file_path': 'coding/AAPL_stockprice.png'}

# %%
from stock import analyze_stock_with_plot

analyze_stock_with_plot("AAPL")
# Out:
# get stock history data: 249
# Plot saved as coding/AAPL_stockprice.png
# {'ticker': 'AAPL',
#  'current_price': 213.49,
#  '52_week_high': 260.1,
#  '52_week_low': 164.08,
#  '50_day_ma': 234.9298,
#  '200_day_ma': 227.77270000000001,
#  'ytd_price_change': 39.77000000000001,
#  'ytd_percent_change': 22.89316140916418,
#  'trend': 'Upward',
#  'volatility': 0.24949738014679793,
#  'plot_file_path': 'coding/AAPL_stockprice.png'}
