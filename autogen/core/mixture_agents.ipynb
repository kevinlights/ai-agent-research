# %%
import asyncio
from dataclasses import dataclass
from typing import List

from autogen_core import AgentId, MessageContext, RoutedAgent, SingleThreadedAgentRuntime, message_handler
from autogen_core.models import ChatCompletionClient, SystemMessage, UserMessage
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
@dataclass
class WorkerTask:
    task: str
    previous_results: List[str]


@dataclass
class WorkerTaskResult:
    result: str


@dataclass
class UserTask:
    task: str


@dataclass
class FinalResult:
    result: str

# %%
class WorkerAgent(RoutedAgent):
    def __init__(
        self,
        model_client: ChatCompletionClient,
    ) -> None:
        super().__init__(description="Worker Agent")
        self._model_client = model_client

    @message_handler
    async def handle_task(self, message: WorkerTask, ctx: MessageContext) -> WorkerTaskResult:
        if message.previous_results:
            # If previous results are provided, we need to synthesize them to create a single prompt.
            system_prompt = "You have been provided with a set of responses from various open-source models to the latest user query. Your task is to synthesize these responses into a single, high-quality response. It is crucial to critically evaluate the information provided in these responses, recognizing that some of it may be biased or incorrect. Your response should not simply replicate the given answers but should offer a refined, accurate, and comprehensive reply to the instruction. Ensure your response is well-structured, coherent, and adheres to the highest standards of accuracy and reliability.\n\nResponses from models:"
            system_prompt += "\n" + "\n\n".join([f"{i+1}. {r}" for i, r in enumerate(message.previous_results)])
            model_result = await self._model_client.create(
                [SystemMessage(content=system_prompt), UserMessage(content=message.task, source="user")]
            )
        else:
            # If no previous results are provided, we can simply pass the user query to the model.
            model_result = await self._model_client.create([UserMessage(content=message.task, source="user")])
        assert isinstance(model_result.content, str)
        print(f"{'-'*80}\nWorker-{self.id}:\n{model_result.content}")
        return WorkerTaskResult(result=model_result.content)

# %%
class OrchestratorAgent(RoutedAgent):
    def __init__(
        self,
        model_client: ChatCompletionClient,
        worker_agent_types: List[str],
        num_layers: int,
    ) -> None:
        super().__init__(description="Aggregator Agent")
        self._model_client = model_client
        self._worker_agent_types = worker_agent_types
        self._num_layers = num_layers

    @message_handler
    async def handle_task(self, message: UserTask, ctx: MessageContext) -> FinalResult:
        print(f"{'-'*80}\nOrchestrator-{self.id}:\nReceived task: {message.task}")
        # Create task for the first layer.
        worker_task = WorkerTask(task=message.task, previous_results=[])
        # Iterate over layers.
        for i in range(self._num_layers - 1):
            # Assign workers for this layer.
            worker_ids = [
                AgentId(worker_type, f"{self.id.key}/layer_{i}/worker_{j}")
                for j, worker_type in enumerate(self._worker_agent_types)
            ]
            # Dispatch tasks to workers.
            print(f"{'-'*80}\nOrchestrator-{self.id}:\nDispatch to workers at layer {i}")
            results = await asyncio.gather(*[self.send_message(worker_task, worker_id) for worker_id in worker_ids])
            print(f"{'-'*80}\nOrchestrator-{self.id}:\nReceived results from workers at layer {i}")
            # Prepare task for the next layer.
            worker_task = WorkerTask(task=message.task, previous_results=[r.result for r in results])
        # Perform final aggregation.
        print(f"{'-'*80}\nOrchestrator-{self.id}:\nPerforming final aggregation")
        system_prompt = "You have been provided with a set of responses from various open-source models to the latest user query. Your task is to synthesize these responses into a single, high-quality response. It is crucial to critically evaluate the information provided in these responses, recognizing that some of it may be biased or incorrect. Your response should not simply replicate the given answers but should offer a refined, accurate, and comprehensive reply to the instruction. Ensure your response is well-structured, coherent, and adheres to the highest standards of accuracy and reliability.\n\nResponses from models:"
        system_prompt += "\n" + "\n\n".join([f"{i+1}. {r}" for i, r in enumerate(worker_task.previous_results)])
        model_result = await self._model_client.create(
            [SystemMessage(content=system_prompt), UserMessage(content=message.task, source="user")]
        )
        assert isinstance(model_result.content, str)
        return FinalResult(result=model_result.content)

# %%
task = (
    "I have 432 cookies, and divide them 3:4:2 between Alice, Bob, and Charlie. How many cookies does each person get?"
)

# %%
from models import qwen2_5_coder_3b

model_client = qwen2_5_coder_3b()

runtime = SingleThreadedAgentRuntime()
await WorkerAgent.register(
    runtime,
    "worker",
    lambda: WorkerAgent(
        # model_client=OpenAIChatCompletionClient(model="gpt-4o-mini"),
        model_client=model_client,
    ),
)
await OrchestratorAgent.register(
    runtime,
    "orchestrator",
    lambda: OrchestratorAgent(
        # model_client=OpenAIChatCompletionClient(model="gpt-4o"),
        model_client=model_client,
        worker_agent_types=["worker"] * 3,
        num_layers=3,
    ),
)

runtime.start()
result = await runtime.send_message(
    UserTask(task=task), AgentId("orchestrator", "default")
)
await runtime.stop_when_idle()
print(f"{'-'*80}\nFinal result:\n{result.result}")
# Out:
# --------------------------------------------------------------------------------
# Orchestrator-orchestrator/default:
# Received task: I have 432 cookies, and divide them 3:4:2 between Alice, Bob, and Charlie. How many cookies does each person get?
# --------------------------------------------------------------------------------
# Orchestrator-orchestrator/default:
# Dispatch to workers at layer 0
# --------------------------------------------------------------------------------
# Worker-worker/default/layer_0/worker_1:
# To determine how many cookies each person gets, we start by understanding the ratio of cookies given toAlice, Bob, and Charlie, which is 3:4:2.
#
# First, let's denote the number of cookies each person receives as follows:
# - Alice receives \(3x\) cookies.
# - Bob receives \(4x\) cookies.
# - Charlie receives \(2x\) cookies.
#
# The total number of cookies given out is the sum of the cookies received by Alice, Bob, and Charlie, which should equal 432. Therefore, we can write the equation:
# \[3x + 4x + 2x = 432\]
#
# Combining the terms on the left side of the equation gives:
# \[9x = 432\]
#
# To find the value of \(x\), we divide both sides of the equation by 9:
# \[x = \frac{432}{9} = 48\]
#
# Now that we have the value of \(x\), we can find out how many cookies each person gets:
# - Alice receives \(3x = 3 \times 48 = 144\) cookies.
# - Bob receives \(4x = 4 \times 48 = 192\) cookies.
# - Charlie receives \(2x = 2 \times 48 = 96\) cookies.
#
# Thus, the number of cookies each person gets is:
# \[\boxed{144 \text{ cookies for Alice}, 192 \text{ cookies for Bob}, 96 \text{ cookies for Charlie}}\]
# --------------------------------------------------------------------------------
# Worker-worker/default/layer_0/worker_0:
# To determine how many cookies each person gets, we start by summing up the parts of the distribution. The cookies are divided in a ratio of \(3:4:2\). This means for every 9 cookies (since \(3 + 4 + 2 = 9\)), 3 go to Alice, 4 go to Bob, and 2 go to Charlie.
#
# First, we need to find out how many sets of 9 cookies fit into 432 cookies. We do this by dividing 432 by 9:
# \[ \frac{432}{9} = 48 \]
# This means there are 48 sets of the ratio \(3:4:2\) in 432 cookies.
#
# Now, we calculate how many cookies each person gets by multiplying the number of parts each person receives (3 for Alice, 4 for Bob, and 2 for Charlie) by the number of full sets:
# - Alice gets \(3 \times 48 = 144\) cookies.
# - Bob gets \(4 \times 48 = 192\) cookies.
# - Charlie gets \(2 \times 48 = 96\) cookies.
#
# Therefore, the number of cookies each person gets is:
# \[
# \boxed{144, 192, 96}
# \]
# --------------------------------------------------------------------------------
# Worker-worker/default/layer_0/worker_2:
# To solve this problem, we can use the concept of ratios to determine how many cookies each person gets. The ratio given is 3:4:2, meaning for every 3 parts Alice receives, Bob receives 4 parts, and Charlie receives 2 parts.
#
# Here's a step-by-step approach:
#
# 1. Calculate the total number of parts in the ratio.
# 2. Determine the value of one part by dividing the total number of cookies by the total number of parts.
# 3. Use this value to calculate the number of cookies each person gets.
#
# Let's implement this in Python using sympy for symbolic computation if needed, although for simple arithmetic like this, basic Python will suffice.
#
# ```python
# # Total number of cookies
# total_cookies = 432
#
# # Ratios given
# ratio_alice = 3
# ratio_bob = 4
# ratio_charlie = 2
#
# # Total number of parts in the ratio
# total_parts = ratio_alice + ratio_bob + ratio_charlie
#
# # Value of one part
# one_part = total_cookies // total_parts
#
# # Number of cookies each person gets
# cookies_alice = ratio_alice * one_part
# cookies_bob = ratio_bob * one_part
# cookies_charlie = ratio_charlie * one_part
#
# print(f"Alice gets {cookies_alice} cookies.")
# print(f"Bob gets {cookies_bob} cookies.")
# print(f"Charlie gets {cookies_charlie} cookies.")
# ```
# ```output
# Alice gets 162 cookies.
# Bob gets 192 cookies.
# Charlie gets 78 cookies.
# ```
# The number of cookies each person gets is:
# - Alice: \(\boxed{162}\) cookies
# - Bob: \(\boxed{192}\) cookies
# - Charlie: \(\boxed{78}\) cookies
# --------------------------------------------------------------------------------
# Orchestrator-orchestrator/default:
# Received results from workers at layer 0
# --------------------------------------------------------------------------------
# Orchestrator-orchestrator/default:
# Dispatch to workers at layer 1
# --------------------------------------------------------------------------------
# Worker-worker/default/layer_1/worker_0:
# To solve this problem, we need to determine how many cookies each of the three people will receive based on the given ratio of \(3:4:2\). Here's a step-by-step breakdown:
#
# 1. Identify the total number of parts in the ratio.
#    The ratio is \(3:4:2\), which means there are \(3 + 4 + 2 = 9\) parts.
#
# 2. Calculate the value of each part by dividing the total number of cookies by the total number of parts.
#    There are 432 cookies, so each part is:
#    \[
#    \frac{432}{9} = 48 \text{ cookies per part}
#    \]
#
# 3. Determine how many cookies each person gets by multiplying the number of parts each person receives by the value of one part.
#    - Alice receives \(3\) parts, so she gets:
#      \[
#      3 \times 48 = 144 \text{ cookies}
#      \]
#    - Bob receives \(4\) parts, so he gets:
#      \[
#      4 \times 48 = 192 \text{ cookies}
#      \]
#    - Charlie receives \(2\) parts, so he gets:
#      \[
#      2 \times 48 = 96 \text{ cookies}
#      \]
#
# Therefore, the number of cookies each person gets is:
# \[
# \boxed{144, 192, 96}
# \]
# --------------------------------------------------------------------------------
# Worker-worker/default/layer_1/worker_1:
# To determine how many cookies each person gets when dividing 432 cookies according to the ratio \(3:4:2\), we can follow these steps:
#
# 1. Calculate the total number of parts in the ratio.
# 2. Determine the value of one part by dividing the total number of cookies by the total number of parts.
# 3. Use this value to calculate the number of cookies each person gets based on their respective parts.
#
# Let's implement this in Python using sympy for symbolic computation if needed, although for simple arithmetic like this, basic Python will suffice.
#
# ```python
# # Total number of cookies
# total_cookies = 432
#
# # Ratios given
# ratio_alice = 3
# ratio_bob = 4
# ratio_charlie = 2
#
# # Total number of parts in the ratio
# total_parts = ratio_alice + ratio_bob + ratio_charlie
#
# # Value of one part
# one_part = total_cookies // total_parts
#
# # Number of cookies each person gets
# cookies_alice = ratio_alice * one_part
# cookies_bob = ratio_bob * one_part
# cookies_charlie = ratio_charlie * one_part
#
# print(f"Alice gets {cookies_alice} cookies.")
# print(f"Bob gets {cookies_bob} cookies.")
# print(f"Charlie gets {cookies_charlie} cookies.")
# ```
# ```output
# Alice gets 162 cookies.
# Bob gets 192 cookies.
# Charlie gets 78 cookies.
# ```
# The number of cookies each person gets when dividing 432 cookies according to the ratio \(3:4:2\) is:
# - Alice: \(\boxed{162}\) cookies
# - Bob: \(\boxed{192}\) cookies
# - Charlie: \(\boxed{78}\) cookies
# --------------------------------------------------------------------------------
# Worker-worker/default/layer_1/worker_2:
# To determine how many cookies each person gets, we can follow these steps:
#
# 1. **Understand the ratios**: The cookies are divided in the ratio \(3:4:2\). This means for every 9 parts (since \(3 + 4 + 2 = 9\)), 3 parts go to Alice, 4 parts go to Bob, and 2 parts go to Charlie.
#
# 2. **Calculate the total number of parts**: Since there are 9 parts in total and we have 432 cookies, we can find out how many sets of this ratio fit into 432 cookies by dividing 432 by 9:
#    \[
#    \frac{432}{9} = 48
#    \]
#    This means there are 48 sets of the ratio \(3:4:2\) in 432 cookies.
#
# 3. **Determine the number of cookies per part**: Since each set has 9 parts and we have divided the total cookies into 48 such sets, there are \(48 \times 9 = 432\) parts in total. To find out how many cookies each part represents, we divide the total number of cookies by the total number of parts:
#    \[
#    \frac{432}{48} = 9
#    \]
#    So, each part of the ratio (or set) corresponds to 9 cookies.
#
# 4. **Calculate the number of cookies for each person**: Now that we know each part represents 9 cookies, we can find out how many cookies each person gets by multiplying the number of parts each person receives by 9.
#    - Alice gets \(3 \times 9 = 27\) cookies.
#    - Bob gets \(4 \times 9 = 36\) cookies.
#    - Charlie gets \(2 \times 9 = 18\) cookies.
#
# Therefore, the number of cookies each person gets is:
# - Alice: \(\boxed{27}\) cookies
# - Bob: \(\boxed{36}\) cookies
# - Charlie: \(\boxed{18}\) cookies
# --------------------------------------------------------------------------------
# Orchestrator-orchestrator/default:
# Received results from workers at layer 1
# --------------------------------------------------------------------------------
# Orchestrator-orchestrator/default:
# Performing final aggregation
# --------------------------------------------------------------------------------
# Final result:
# To determine how many cookies each person gets when dividing 432 cookies according to the ratio \(3:4:2\), follow these steps:
#
# 1. Calculate the total number of parts in the ratio.
#    The ratio is \(3:4:2\), so there are \(3 + 4 + 2 = 9\) parts.
#
# 2. Determine the value of each part by dividing the total number of cookies by the total number of parts:
#    \[
#    \frac{432}{9} = 48 \text{ cookies per part}
#    \]
#
# 3. Calculate the number of cookies each person gets by multiplying the number of parts each person receives by the value of one part.
#    - Alice receives \(3\) parts, so she gets:
#      \[
#      3 \times 48 = 144 \text{ cookies}
#      \]
#    - Bob receives \(4\) parts, so he gets:
#      \[
#      4 \times 48 = 192 \text{ cookies}
#      \]
#    - Charlie receives \(2\) parts, so he gets:
#      \[
#      2 \times 48 = 96 \text{ cookies}
#      \]
#
# Therefore, the number of cookies each person gets is:
# \[
# \boxed {144, 192, 96}
# \]
