# %%
from dataclasses import dataclass

from autogen_core import (
    MessageContext,
    RoutedAgent,
    SingleThreadedAgentRuntime,
    TopicId,
    TypeSubscription,
    message_handler,
    type_subscription,
)
from autogen_core.models import ChatCompletionClient, SystemMessage, UserMessage
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
@dataclass
class Message:
    content: str

# %%
concept_extractor_topic_type = "ConceptExtractorAgent"
writer_topic_type = "WriterAgent"
format_proof_topic_type = "FormatProofAgent"
user_topic_type = "User"

# %%
@type_subscription(topic_type=concept_extractor_topic_type)
class ConceptExtractorAgent(RoutedAgent):
    def __init__(self, model_client: ChatCompletionClient) -> None:
        super().__init__("A concept extractor agent.")
        self._system_message = SystemMessage(
            content=(
                "You are a marketing analyst. Given a product description, identify:\n"
                "- Key features\n"
                "- Target audience\n"
                "- Unique selling points\n\n"
            )
        )
        self._model_client = model_client

    @message_handler
    async def handle_user_description(self, message: Message, ctx: MessageContext) -> None:
        prompt = f"Product description: {message.content}"
        llm_result = await self._model_client.create(
            messages=[self._system_message, UserMessage(content=prompt, source=self.id.key)],
            cancellation_token=ctx.cancellation_token,
        )
        response = llm_result.content
        assert isinstance(response, str)
        print(f"{'-'*80}\n{self.id.type}:\n{response}")

        await self.publish_message(Message(response), topic_id=TopicId(writer_topic_type, source=self.id.key))

# %%
@type_subscription(topic_type=writer_topic_type)
class WriterAgent(RoutedAgent):
    def __init__(self, model_client: ChatCompletionClient) -> None:
        super().__init__("A writer agent.")
        self._system_message = SystemMessage(
            content=(
                "You are a marketing copywriter. Given a block of text describing features, audience, and USPs, "
                "compose a compelling marketing copy (like a newsletter section) that highlights these points. "
                "Output should be short (around 150 words), output just the copy as a single text block."
            )
        )
        self._model_client = model_client

    @message_handler
    async def handle_intermediate_text(self, message: Message, ctx: MessageContext) -> None:
        prompt = f"Below is the info about the product:\n\n{message.content}"

        llm_result = await self._model_client.create(
            messages=[self._system_message, UserMessage(content=prompt, source=self.id.key)],
            cancellation_token=ctx.cancellation_token,
        )
        response = llm_result.content
        assert isinstance(response, str)
        print(f"{'-'*80}\n{self.id.type}:\n{response}")

        await self.publish_message(Message(response), topic_id=TopicId(format_proof_topic_type, source=self.id.key))

# %%
@type_subscription(topic_type=format_proof_topic_type)
class FormatProofAgent(RoutedAgent):
    def __init__(self, model_client: ChatCompletionClient) -> None:
        super().__init__("A format & proof agent.")
        self._system_message = SystemMessage(
            content=(
                "You are an editor. Given the draft copy, correct grammar, improve clarity, ensure consistent tone, "
                "give format and make it polished. Output the final improved copy as a single text block."
            )
        )
        self._model_client = model_client

    @message_handler
    async def handle_intermediate_text(self, message: Message, ctx: MessageContext) -> None:
        prompt = f"Draft copy:\n{message.content}."
        llm_result = await self._model_client.create(
            messages=[self._system_message, UserMessage(content=prompt, source=self.id.key)],
            cancellation_token=ctx.cancellation_token,
        )
        response = llm_result.content
        assert isinstance(response, str)
        print(f"{'-'*80}\n{self.id.type}:\n{response}")

        await self.publish_message(Message(response), topic_id=TopicId(user_topic_type, source=self.id.key))

# %%
@type_subscription(topic_type=user_topic_type)
class UserAgent(RoutedAgent):
    def __init__(self) -> None:
        super().__init__("A user agent that outputs the final copy to the user.")

    @message_handler
    async def handle_final_copy(self, message: Message, ctx: MessageContext) -> None:
        print(f"\n{'-'*80}\n{self.id.type} received final copy:\n{message.content}")

# %%
# model_client = OpenAIChatCompletionClient(
#     model="gpt-4o-mini",
#     # api_key="YOUR_API_KEY"
# )
from models import qwen_25_1_5b

model_client = qwen_25_1_5b()

runtime = SingleThreadedAgentRuntime()

await ConceptExtractorAgent.register(
    runtime,
    type=concept_extractor_topic_type,
    factory=lambda: ConceptExtractorAgent(model_client=model_client),
)

await WriterAgent.register(
    runtime,
    type=writer_topic_type,
    factory=lambda: WriterAgent(model_client=model_client),
)

await FormatProofAgent.register(
    runtime,
    type=format_proof_topic_type,
    factory=lambda: FormatProofAgent(model_client=model_client),
)

await UserAgent.register(runtime, type=user_topic_type, factory=lambda: UserAgent())
# Out:
# AgentType(type='User')

# %%
runtime.start()

await runtime.publish_message(
    Message(
        content="An eco-friendly stainless steel water bottle that keeps drinks cold for 24 hours"
    ),
    topic_id=TopicId(concept_extractor_topic_type, source="default"),
)

await runtime.stop_when_idle()
# Out:
# --------------------------------------------------------------------------------
# ConceptExtractorAgent:
# Key Features:
# - Made from 18/8 food-grade stainless steel to ensure safety and durability.
# - Keeps drink cold up to 24 hours with insulation properties.
# - Meets USDA nutrition facts labels for easy reference.
# - Lightweight and compact design that fits easily in a bag or pouch.
#
# Target Audience:
# This product is primarily intended for environmentally conscious individuals who are looking for sustainable alternatives to plastic bottles. It appeals especially to office workers, outdoor enthusiasts, and students seeking practical solutions.
#
# Unique Selling Points:
# - Sustainable material - Made from 18/8 stainless steel that's approved for food safety.
# - Long-term effectiveness - Keeps drinks cold for up to 24 hours with insulation technology.
# - Compact design - Lightweight and portable, suitable for daily use or on the go.
# - Health awareness - Encourages healthier hydration habits by meeting USDA nutritional standards.
# --------------------------------------------------------------------------------
# WriterAgent:
# "Stay Hydrated Naturally: Embrace Sustainable Sipping Solutions! 🌿💪
#
# Say goodbye to cheap plastic bottles and hello to our cutting-edge stainless steel drink containers—from 18/8 food-grade steel that meets rigorous safety standards—and enjoy the following benefits:
#
# 🌿 Our products are sustainably made from 100% recyclable stainless steel, making them an eco-friendly choice. Each sip is as safe and hygienic as the next.
#
# ⏰ Cold for Days: Say goodbye to lukewarm drinks thanks to our advanced insulation technology that keeps beverages cold for up to 24 hours. It’s perfect for those on-the-go moments or keeping essentials cool at work.
# 💼 Perfectly Portable: Designed to be lightweight, compact, and easy to carry anywhere, whether you’re in an office workspace, a hiking trail, or a classroom. Perfect for everyday use or emergencies.
#
# 🌿 Health-At-The-Halt: These containers offer USDA nutrition labels on the side, making dietary awareness as intuitive as the drink itself. Enjoy healthier hydration habits every day without sacrificing taste and convenience.
# 💧 Eco-Friendly Drinking: Upgrade your beverages' journey from faucet to you in a sustainably certified stainless steel world where each sip counts.
#
# Stay hydrated with confidence knowing our products are both sustainable and superior when it comes to keeping drinks cold or hot longer than plastic equivalents. Join the growing number of eco-conscious individuals striving for healthier, more durable habits by choosing 100% healthy beverages."
#
# ---
#
# This copy highlights how the product aligns with its key features, target audience, and unique selling points while encouraging the readers to adopt a more responsible drinking culture.
# --------------------------------------------------------------------------------
# FormatProofAgent:
# Stay Hydrated Naturally: Embrace Sustainable Sipping Solutions!🌿💪
#
# Say goodbye to cheap plastic bottles, hello to our cutting-edge stainless steel drink containers. Made from 100% recyclable 18/8 food-grade steel that meets rigorous safety standards—each sip is as safe and hygienic as the next.
#
# Cold for Days: Eliminate lukewarm drinks thanks to advanced insulation technology that keeps beverages cool up to 24 hours, perfect for on-the-go moments or keeping essentials cool at work 💼
#
# Perfectly Portable: Designed for daily use, these lightweight containers can be carried anywhere. Whether you're an office worker, hiker, classroom student, or simply need a portable addition to your liquid intake 🛠️
#
# Health-At-The-Halt Containers offer USDA nutrition labels on the side, making dietary awareness intuitive and effortless. Enjoy healthier hydration habits each day without giving up the taste of the drink 💃‌
#
# Eco-Friendly Drinking: Upgrade your beverages' journey from faucet to sink in a sustainably certified stainless steel world where each sip counts 🌿
#
# Join the growing number of eco-conscious individuals, by choosing 100% healthy beverages knowing that our products are both sustainable and superior when it comes to keeping drinks cold or hot longer than plastic equivalents 💦👍
#
# Stay hydrated and feel confident you're drinking responsibly with these sustainable stainless steel drink containers.
#
# --------------------------------------------------------------------------------
# User received final copy:
# Stay Hydrated Naturally: Embrace Sustainable Sipping Solutions!🌿💪
#
# Say goodbye to cheap plastic bottles, hello to our cutting-edge stainless steel drink containers. Made from 100% recyclable 18/8 food-grade steel that meets rigorous safety standards—each sip is as safe and hygienic as the next.
#
# Cold for Days: Eliminate lukewarm drinks thanks to advanced insulation technology that keeps beverages cool up to 24 hours, perfect for on-the-go moments or keeping essentials cool at work 💼
#
# Perfectly Portable: Designed for daily use, these lightweight containers can be carried anywhere. Whether you're an office worker, hiker, classroom student, or simply need a portable addition to your liquid intake 🛠️
#
# Health-At-The-Halt Containers offer USDA nutrition labels on the side, making dietary awareness intuitive and effortless. Enjoy healthier hydration habits each day without giving up the taste of the drink 💃‌
#
# Eco-Friendly Drinking: Upgrade your beverages' journey from faucet to sink in a sustainably certified stainless steel world where each sip counts 🌿
#
# Join the growing number of eco-conscious individuals, by choosing 100% healthy beverages knowing that our products are both sustainable and superior when it comes to keeping drinks cold or hot longer than plastic equivalents 💦👍
#
# Stay hydrated and feel confident you're drinking responsibly with these sustainable stainless steel drink containers.
